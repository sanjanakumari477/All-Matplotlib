# %%
import matplotlib.pyplot as plt 
import matplotlib.pyplot as plt

# students data 
scores = [45, 56, 67, 70, 72, 75, 78, 80, 82, 85, 87, 88, 90, 91, 92, 94, 95, 97, 98, 100,
          55, 60, 65, 68, 73, 76, 79, 83, 86, 89, 93, 96, 99, 40, 42, 58, 63, 69, 74, 81]

# Create histogram
plt.hist(scores, bins=10, color='plum', edgecolor='black')
plt.xlabel("Score Range")
plt.ylabel("Number of Students")
plt.title("Distribution of Student Exam Scores")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
